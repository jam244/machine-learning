# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen , Request
from datetime import datetime
import matplotlib.pyplot as plt

# %%
import requests
import pandas as pd

# links are being loaded dynamically in page. You neeed to inspect the Network tab in Dev tools,
# and you will notice an XHR call is being made to an API, which returns a JSON response. 
# The following code will get you the information loaded by javascript in page:

def create_url_and_header(symbol):
    headers = {
        'authority': 'news-headlines.tradingview.com',
        'method': 'GET',
        'path': f'/headlines/?category=stock&lang=en&symbol=NSE%3A{symbol}',
        'scheme': 'https',
        'accept': '*/*',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.9',
        'origin': 'https://www.tradingview.com',
        'referer': 'https://www.tradingview.com/',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-site',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36'
    }
    url=f'https://news-headlines.tradingview.com/headlines/?category=stock&lang=en&symbol=NSE%3A{symbol}'
    
    return headers, url

# %%
tickers = ['TORNTPHARM', 'YESBANK', 'TIINDIA']

date_to_check_till = datetime(2022, 1, 1)

data=[]
for ticker in tickers:
    headers, url = create_url_and_header(ticker)
    r = requests.get(url, headers=headers)
    num_headlines = len(r.json())
    for i in range(num_headlines):
        headline = r.json()[i]['title']
        date = datetime.fromtimestamp(r.json()[i]['published'])
        if date >= date_to_check_till:
            data.append([ticker , date, headline])
        
columns = ["ticker", "date", "news"]
news_df = pd.DataFrame(data, columns=columns)
display(news_df)
# Out:
#         ticker                date  \
# 0   TORNTPHARM 2022-05-27 04:08:48
# 1   TORNTPHARM 2022-05-26 10:22:12
# 2   TORNTPHARM 2022-05-26 01:46:16
# 3   TORNTPHARM 2022-05-23 07:18:47
# 4   TORNTPHARM 2022-03-18 04:00:16
# 5   TORNTPHARM 2022-03-09 10:59:04
# 6   TORNTPHARM 2022-01-26 05:50:48
# 7   TORNTPHARM 2022-01-10 07:11:33
# 8      YESBANK 2022-07-25 05:07:33
# 9      YESBANK 2022-07-19 09:15:27
# 10     YESBANK 2022-07-19 08:14:57
# 11     YESBANK 2022-07-15 12:43:08
# 12     YESBANK 2022-06-22 07:10:10
# 13     YESBANK 2022-06-21 06:00:18
# 14     YESBANK 2022-06-20 06:32:01
# 15     YESBANK 2022-06-16 04:53:44
# 16     YESBANK 2022-06-09 08:47:16
# 17     YESBANK 2022-05-02 11:52:38
# 18     YESBANK 2022-03-23 03:19:13
# 19     YESBANK 2022-02-04 04:46:34
# 20     YESBANK 2022-01-24 10:12:32
# 21     YESBANK 2022-01-05 02:21:48
# 22     TIINDIA 2022-07-22 03:05:47
# 23     TIINDIA 2022-07-19 02:52:53
# 24     TIINDIA 2022-05-05 03:53:40
# 25     TIINDIA 2022-03-03 02:49:57
# 26     TIINDIA 2022-02-14 09:07:54
# 27     TIINDIA 2022-02-08 09:31:58
# 28     TIINDIA 2022-01-24 23:54:27
#
#                                                  news
# 0   Torrent Pharmaceuticals to Acquire Four Brands...
# 1   Torrent Pharmaceuticals Turns to Loss in Fisca...
# 2   Torrent Pharmaceuticals Plans to Raise Up to $...
# 3   Torrent Pharmaceuticals Board to Consider Issu...
# 4   Torrent Pharmaceuticals Signs License Pact for...
# 5   Indian companies stay put in Russia but pharma...
# 6   Torrent Pharma's Profit Drops 16% in Fiscal Q3...
# 7   Torrent Pharmaceuticals Board to Consider Inte...
# 8   Yes Bank's Fiscal Q1 Consolidated Net Profit, ...
# 9   Market Chatter: Yes Bank Plans $1 Billion Fund...
# 10  Market Chatter: Yes Bank Eyes Up To 20% Stake ...
# 11  Yes Bank Selects JC Flowers ARC as Base Bidder...
# 12  Yes Bank Appoints New Country Head of Branch B...
# 13  Market Chatter: YES Bank Nears $1 Billion Inve...
# 14  Market Chatter: Private Equity Major Carlyle G...
# 15  YES Bank to Seek Shareholders Nod for $1.3 Bil...
# 16  Yes Bank Poised to Exit Reconstruction Scheme;...
# 17              YES Bank Turns to Profit in Fiscal Q4
# 18  Market Chatter: Yes Bank in Talks With Private...
# 19  PE firm Advent eyeing $1 bln investment in Ind...
# 20  YES Bank's Consolidated Net Profit Jumps in Fi...
# 21  YES Bank's Net Advances Jumps Nearly 4% by Dec...
# 22  Tube Investments of India to Acquire 76% Stake...
# 23  Tube Investments Arm to Acquire 65% Stake in E...
# 24  Tube Investments Board Approves Plan to Raise ...
# 25  Tube Investments Of India Subscribes to Subsid...
# 26  Tube Investments of India to Form Clean Mobili...
# 27  Tube Investments Of India Posts Sharp Increase...
# 28  Tube Investments Of India to Acquire Up To 70%...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

vader = SentimentIntensityAnalyzer()

scores = news_df['news'].apply(vader.polarity_scores).tolist()
scores_df = pd.DataFrame(scores)

display(scores_df)

news_df = news_df.join(scores_df, rsuffix='_right')
news_df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\John.Matthew\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#      neg    neu    pos  compound
# 0   0.00  1.000  0.000    0.0000
# 1   0.17  0.667  0.163   -0.0258
# 2   0.00  1.000  0.000    0.0000
# 3   0.00  0.551  0.449    0.6908
# 4   0.00  1.000  0.000    0.0000
# 5   0.00  1.000  0.000    0.0000
# 6   0.11  0.690  0.200    0.3182
# 7   0.00  1.000  0.000    0.0000
# 8   0.00  0.556  0.444    0.6808
# 9   0.00  0.787  0.213    0.4019
# 10  0.00  0.755  0.245    0.6369
# 11  0.14  0.702  0.158    0.0772
# 12  0.00  0.748  0.252    0.4019
# 13  0.00  0.778  0.222    0.5319
# 14  0.00  0.762  0.238    0.5319
# 15  0.00  0.744  0.256    0.5319
# 16  0.00  0.585  0.415    0.7783
# 17  0.00  0.486  0.514    0.7456
# 18  0.00  0.847  0.153    0.4019
# 19  0.00  0.816  0.184    0.4019
# 20  0.00  0.525  0.475    0.7456
# 21  0.00  0.700  0.300    0.5319
# 22  0.00  1.000  0.000    0.0000
# 23  0.00  1.000  0.000    0.0000
# 24  0.00  0.787  0.213    0.4019
# 25  0.00  1.000  0.000    0.0000
# 26  0.00  0.671  0.329    0.5994
# 27  0.00  0.679  0.321    0.6369
# 28  0.00  1.000  0.000    0.0000
#        ticker                date  \
# 0  TORNTPHARM 2022-05-27 04:08:48
# 1  TORNTPHARM 2022-05-26 10:22:12
# 2  TORNTPHARM 2022-05-26 01:46:16
# 3  TORNTPHARM 2022-05-23 07:18:47
# 4  TORNTPHARM 2022-03-18 04:00:16
#
#                                                 news   neg    neu    pos  \
# 0  Torrent Pharmaceuticals to Acquire Four Brands...  0.00  1.000  0.000
# 1  Torrent Pharmaceuticals Turns to Loss in Fisca...  0.17  0.667  0.163
# 2  Torrent Pharmaceuticals Plans to Raise Up to $...  0.00  1.000  0.000
# 3  Torrent Pharmaceuticals Board to Consider Issu...  0.00  0.551  0.449
# 4  Torrent Pharmaceuticals Signs License Pact for...  0.00  1.000  0.000
#
#    compound
# 0    0.0000
# 1   -0.0258
# 2    0.0000
# 3    0.6908
# 4    0.0000

# %%
mean_scores = news_df.groupby(['ticker', 'date']).mean()
print(mean_scores)
mean_scores = mean_scores.unstack()
print(mean_scores)
mean_scores = mean_scores.xs('compound', axis="columns").transpose()
plt.rcParams['figure.figsize'] = [10, 6]
mean_scores.plot(kind='bar')
plt.show()
# Out:
#                                  neg    neu    pos  compound
# ticker     date
# TIINDIA    2022-01-24 23:54:27  0.00  1.000  0.000    0.0000
#            2022-02-08 09:31:58  0.00  0.679  0.321    0.6369
#            2022-02-14 09:07:54  0.00  0.671  0.329    0.5994
#            2022-03-03 02:49:57  0.00  1.000  0.000    0.0000
#            2022-05-05 03:53:40  0.00  0.787  0.213    0.4019
#            2022-07-19 02:52:53  0.00  1.000  0.000    0.0000
#            2022-07-22 03:05:47  0.00  1.000  0.000    0.0000
# TORNTPHARM 2022-01-10 07:11:33  0.00  1.000  0.000    0.0000
#            2022-01-26 05:50:48  0.11  0.690  0.200    0.3182
#            2022-03-09 10:59:04  0.00  1.000  0.000    0.0000
#            2022-03-18 04:00:16  0.00  1.000  0.000    0.0000
#            2022-05-23 07:18:47  0.00  0.551  0.449    0.6908
#            2022-05-26 01:46:16  0.00  1.000  0.000    0.0000
#            2022-05-26 10:22:12  0.17  0.667  0.163   -0.0258
#            2022-05-27 04:08:48  0.00  1.000  0.000    0.0000
# YESBANK    2022-01-05 02:21:48  0.00  0.700  0.300    0.5319
#            2022-01-24 10:12:32  0.00  0.525  0.475    0.7456
#            2022-02-04 04:46:34  0.00  0.816  0.184    0.4019
#            2022-03-23 03:19:13  0.00  0.847  0.153    0.4019
#            2022-05-02 11:52:38  0.00  0.486  0.514    0.7456
#            2022-06-09 08:47:16  0.00  0.585  0.415    0.7783
#            2022-06-16 04:53:44  0.00  0.744  0.256    0.5319
#            2022-06-20 06:32:01  0.00  0.762  0.238    0.5319
#            2022-06-21 06:00:18  0.00  0.778  0.222    0.5319
#            2022-06-22 07:10:10  0.00  0.748  0.252    0.4019
#            2022-07-15 12:43:08  0.14  0.702  0.158    0.0772
#            2022-07-19 08:14:57  0.00  0.755  0.245    0.6369
#            2022-07-19 09:15:27  0.00  0.787  0.213    0.4019
#            2022-07-25 05:07:33  0.00  0.556  0.444    0.6808
#                            neg                                          \
# date       2022-01-05 02:21:48 2022-01-10 07:11:33 2022-01-24 10:12:32
# ticker
# TIINDIA                    NaN                 NaN                 NaN
# TORNTPHARM                 NaN                 0.0                 NaN
# YESBANK                    0.0                 NaN                 0.0
#
#                                                                         \
# date       2022-01-24 23:54:27 2022-01-26 05:50:48 2022-02-04 04:46:34
# ticker
# TIINDIA                    0.0                 NaN                 NaN
# TORNTPHARM                 NaN                0.11                 NaN
# YESBANK                    NaN                 NaN                 0.0
#
#                                                                         \
# date       2022-02-08 09:31:58 2022-02-14 09:07:54 2022-03-03 02:49:57
# ticker
# TIINDIA                    0.0                 0.0                 0.0
# TORNTPHARM                 NaN                 NaN                 NaN
# YESBANK                    NaN                 NaN                 NaN
#
#                                 ...            compound                      \
# date       2022-03-09 10:59:04  ... 2022-06-16 04:53:44 2022-06-20 06:32:01
# ticker                          ...
# TIINDIA                    NaN  ...                 NaN                 NaN
# TORNTPHARM                 0.0  ...                 NaN                 NaN
# YESBANK                    NaN  ...              0.5319              0.5319
#
#                                                                         \
# date       2022-06-21 06:00:18 2022-06-22 07:10:10 2022-07-15 12:43:08
# ticker
# TIINDIA                    NaN                 NaN                 NaN
# TORNTPHARM                 NaN                 NaN                 NaN
# YESBANK                 0.5319              0.4019              0.0772
#
#                                                                         \
# date       2022-07-19 02:52:53 2022-07-19 08:14:57 2022-07-19 09:15:27
# ticker
# TIINDIA                    0.0                 NaN                 NaN
# TORNTPHARM                 NaN                 NaN                 NaN
# YESBANK                    NaN              0.6369              0.4019
#
#
# date       2022-07-22 03:05:47 2022-07-25 05:07:33
# ticker
# TIINDIA                    0.0                 NaN
# TORNTPHARM                 NaN                 NaN
# YESBANK                    NaN              0.6808
#
# [3 rows x 116 columns]
